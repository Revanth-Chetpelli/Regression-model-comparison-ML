# %% [markdown]
# <a href="https://colab.research.google.com/github/Revanth-Chetpelli/Regression-model-comparison-ML/blob/main/covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load the data

# %%
import pandas as pd

# %%
df=pd.read_csv('case_time_series.csv')
df
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0     30 January                 1                1                0
# 1     31 January                 0                1                0
# 2    01 February                 0                1                0
# 3    02 February                 1                2                0
# 4    03 February                 1                3                0
# ..            ...              ...              ...              ...
# 100       09 May              3175            62865             1414
# 101       10 May              4311            67176             1669
# 102       11 May              3592            70768             1579
# 103       12 May              3562            74330             1905
# 104       13 May              3726            78056             1964
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# ...

# %%
df.shape
# Out:
# (105, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             105 non-null    object
#  1   Daily Confirmed  105 non-null    int64
#  2   Total Confirmed  105 non-null    int64
#  3   Daily Recovered  105 non-null    int64
#  4   Total Recovered  105 non-null    int64
#  5   Daily Deceased   105 non-null    int64
#  6   Total Deceased   105 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 5.9+ KB

# %%
df.isnull().sum()
# Out:
# Date               0
# Daily Confirmed    0
# Total Confirmed    0
# Daily Recovered    0
# Total Recovered    0
# Daily Deceased     0
# Total Deceased     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
x=df.iloc[61:,0]
y=df.iloc[61:,1]
plt.figure(figsize=(20,8))
ax=plt.axes()
ax.grid(color='#f8f8f8',linewidth=1.0)
ax.set_facecolor('black')
ax.set_xlabel('Date',color='red',size=40)
ax.set_ylabel('No.of Cases',color='green',size=40)
plt.xticks(rotation='vertical',color='red',size=10)
plt.tick_params(color='white',size=20)
for i,j in zip(x,y):
    ax.annotate(j,xy=(i,j),color='white',size=12)
ax.annotate('Second Lockdown April 15 2021',
            xy=(15.2,860),
            xytext=(19.2,500),
            color='white',
            size=25,
            arrowprops=dict(color='white',linewidth=1.0))
plt.plot(x,y,marker='o',ms=12)
plt.title('Covid19 Second lockdown',size=50)
plt.savefig('covid19.pdf')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
